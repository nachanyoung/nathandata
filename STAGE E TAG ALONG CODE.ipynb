# %% [markdown]
# # CONSOLIDATED STATEMENTS OF INCOME - USD Dollars in Millions

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import links to excel dataset downloaded from Coca-Cola Financial Page fcovering 2009 to 2019

# %%
link1 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2011 FY.csv'
link2 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2011 Q3.csv'
link3 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2011 Q2.csv'
link4 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2012 FY.csv'
link5 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2012 Q3.csv'
link6 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2012 Q2.csv'
link7 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2012 Q1.csv'
link8 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2013 FY.csv'
link9 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2013 Q3.csv'
link10 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2013 Q2.csv'
link11 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2013 Q1.csv'
link12 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2014 FY.csv'
link13 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2014 Q3.csv'
link14 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2014 Q2.csv'
link15 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2014 Q1.csv'
link16 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2015 FY.csv'
link17 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2015 Q3.csv'
link18 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2015 Q2.csv'
link19 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2015 Q1.csv'
link20 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2016 FY.csv'
link21 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2016 Q3.csv'
link22 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2016 Q2.csv'
link23 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2016 Q1.csv'
linK24 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2017 FY.csv'
link25 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2017 Q3.csv'
link26 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2017 Q2.csv'
link27 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2017 Q1.csv'
link28 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2018 FY.csv'
link29 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2018 Q3.csv'
link30 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2018 Q2.csv'
link31 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2018 Q1.csv'
link32 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2019 FY.csv'
link33 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2019 Q3.csv'
link34 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2019 Q2.csv'
link35 = r'\Users\Anih Nathan\OneDrive\Desktop\CocaColaFinance\Income\2019 Q1.csv'
link1frame = pd.read_csv(link1)
link2frame = pd.read_csv(link2, encoding = 'unicode_escape')
link3frame = pd.read_csv(link3, encoding = 'unicode_escape')
link4frame = pd.read_csv(link4)
link5frame = pd.read_csv(link5)
link6frame = pd.read_csv(link6)
link7frame = pd.read_csv(link7)
link8frame = pd.read_csv(link8)
link9frame = pd.read_csv(link9)
link10frame = pd.read_csv(link10)
link11frame = pd.read_csv(link11)
link12frame = pd.read_csv(link12)
link13frame = pd.read_csv(link13)
link14frame = pd.read_csv(link14)
link15frame = pd.read_csv(link15)
link16frame = pd.read_csv(link16)
link17frame = pd.read_csv(link17)
link18frame = pd.read_csv(link18)
link19frame = pd.read_csv(link19)
link20frame = pd.read_csv(link20)
link21frame = pd.read_csv(link21)
link22frame = pd.read_csv(link22)
link23frame = pd.read_csv(link23)
link24frame = pd.read_csv(linK24, encoding = 'unicode_escape')
link25frame = pd.read_csv(link25)
link26frame = pd.read_csv(link26)
link27frame = pd.read_csv(link27)
link28frame = pd.read_csv(link28)
link29frame = pd.read_csv(link29)
link30frame = pd.read_csv(link30)
link31frame = pd.read_csv(link31)
link32frame = pd.read_csv(link32)
link33frame = pd.read_csv(link33)
link34frame = pd.read_csv(link34, encoding = 'unicode_escape')
link35frame = pd.read_csv(link35)


link3frame
# Out:
#                                           Description Jul. 01, 2011  \
# 0                              NET OPERATING REVENUES      $ 12,737
# 1                                  Cost of goods sold         4,989
# 2                                        GROSS PROFIT         7,748
# 3        Selling, general and administrative expenses         4,422
# 4                             Other operating charges           152
# 5                                    OPERATING INCOME         3,174
# 6                                     Interest income           121
# 7                                    Interest expense            84
# 8                          Equity income (loss) - net           221
# 9                           Other income (loss) - net           362
# 10                         INCOME BEFORE INCOME TAXES         3,794
# 11                                       Income taxes           990
# 12                            CONSOLIDATED NET INCOME         2,804
# ...

# %% [markdown]
# ### Transpose Dataset

# %%
income1 = link1frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income2 = link2frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income3 = link3frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income4 = link4frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income5 = link5frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income6 = link6frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income7 = link7frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income8 = link8frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income9 = link9frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income10 = link10frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income11 = link11frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income12 = link12frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income13 = link13frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income14 = link14frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income15 = link15frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income16 = link16frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income17 = link17frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income18 = link18frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income19 = link19frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income20 = link20frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income21 = link21frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income22 = link22frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income23 = link23frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income24 = link24frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income25 = link25frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income26 = link26frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income27 = link27frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income28 = link28frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income29 = link29frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income30 = link30frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income31 = link31frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income32 = link32frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income33 = link33frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income34 = link34frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
income35 = link35frame.set_index('Description').unstack().unstack().reset_index(names='Date').rename_axis(columns=None)
#view one of the transpose as a sample for correctness
income3
# Out:
#             Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# 0  Jul. 01, 2011               $ 12,737              4,989        7,748
# 1  Jul. 02, 2010                $ 8,674              2,955        5,719
#
#   Selling, general and administrative expenses Other operating charges  \
# 0                                        4,422                     152
# 1                                        2,878                      78
#
#   OPERATING INCOME Interest income Interest expense  \
# 0            3,174             121               84
# 1            2,763              67               81
#
#   Equity income (loss) - net  ... Income taxes CONSOLIDATED NET INCOME  \
# 0                        221  ...          990                   2,804
# 1                        356  ...          741                   2,382
#
#   Less: Net income attributable to noncontrolling interests  \
# 0                                                  7
# ...

# %% [markdown]
# ### Merge all transposed data

# %%
financialdata = pd.concat([income1,income2,income3,income4,income5,income6,income7,income8,income9,income10,income11,income12,income13,income14,income15,income16,income17,income18,income19,income20,income21,income22,income23,income24,income25,income26,income27,income28,income29,income30,income31,income32,income33,income34,income35],axis=0,ignore_index=True)

# %%
financialdata.sort_values(by=['Date'])
# Out:
#              Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# 15  Apr. 01, 2011               $10,517               3,948        6,569
# 41  Apr. 01, 2016              $ 10,282              4,069        6,213
# 60  Apr. 01, 2016              $ 10,282              4,069        6,213
# 42  Apr. 03, 2015              $ 10,711              4,103        6,608
# 50  Apr. 03, 2015               $10,711               4,103        6,608
# ..            ...                    ...                ...          ...
# 55  Sep. 29, 2017               $ 9,078              3,395        5,683
# 3   Sep. 30, 2011               $ 12,248              4,875        7,373
# 11  Sep. 30, 2011               $12,248               4,875        7,373
# 56  Sep. 30, 2016              $ 10,633              4,131        6,502
# 46  Sep. 30, 2016              $ 10,633              4,131        6,502
#
#    Selling, general and administrative expenses Other operating charges  \
# ...

# %%
financialdata.describe()
# Out:
#                  Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# count              79                     79                 79           79
# unique             40                     55                 53           54
# top     Dec. 31, 2011               $46,542               4,989      25,398
# freq                3                      3                  3            3
#
#        Selling, general and administrative expenses Other operating charges  \
# count                                            76                      79
# unique                                           56                      51
# top                                         16,427                      732
# freq                                              3                       3
#
#        OPERATING INCOME Interest income Interest expense  \
# count                79              79               79
# unique               59              45               48
# ...

# %% [markdown]
# ### Some columns appear twice because differently years entered them slightly different. E.g _Selling, general and administrative expenses_ is practically same as _Selling, General and Administrative Expense_.  All such columns were merged after which one is discarded

# %%
financialdata['Other income (loss) - net'].fillna(financialdata['Other income (loss)  net'], inplace=True)
del financialdata['Other income (loss)  net']

# %%
financialdata['Selling, general and administrative expenses'].fillna(financialdata['Selling, General and Administrative Expense'], inplace=True)
del financialdata['Selling, General and Administrative Expense']

# %%
financialdata['Less: Net income (loss) attributable to noncontrolling interests'].fillna(financialdata['Less: Net income attributable to noncontrolling interests'], inplace=True)
del financialdata['Less: Net income attributable to noncontrolling interests']

# %%
financialdata['Net Income from Continuing Operations'].fillna(financialdata['NET INCOME FROM CONTINUING OPERATIONS'], inplace=True)
del financialdata['NET INCOME FROM CONTINUING OPERATIONS']

# %%
financialdata['Income (Loss) from Discontinued Operations (net of income taxes)'].fillna(financialdata['Income from Discontinued Operations (net of income taxes)'], inplace=True)
del financialdata['Income from Discontinued Operations (net of income taxes)']

# %%
financialdata.describe()
# Out:
#                  Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# count              79                     79                 79           79
# unique             40                     55                 53           54
# top     Dec. 31, 2011               $46,542               4,989      25,398
# freq                3                      3                  3            3
#
#        Selling, general and administrative expenses Other operating charges  \
# count                                            79                      79
# unique                                           59                      51
# top                                         16,427                      732
# freq                                              3                       3
#
#        OPERATING INCOME Interest income Interest expense  \
# count                79              79               79
# unique               59              45               48
# ...

# %% [markdown]
# ### Check for null columns

# %%
financialdata.isnull().sum()
# Out:
# Date                                                                                                                  0
# NET OPERATING REVENUES                                                                                                0
# Cost of goods sold                                                                                                    0
# GROSS PROFIT                                                                                                          0
# Selling, general and administrative expenses                                                                          0
# Other operating charges                                                                                               0
# OPERATING INCOME                                                                                                      0
# Interest income                                                                                                       0
# ...

# %% [markdown]
# ### Check if duplicate columns exist

# %%
financialdata[financialdata.duplicated('Date')]
# Out:
#              Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# 8   Dec. 31, 2011               $46,542              18,215       28,327
# 9   Dec. 31, 2010               $35,119              12,693       22,426
# 11  Sep. 30, 2011               $12,248               4,875        7,373
# 13  Jul. 01, 2011                12737.0             4989.0       7748.0
# 17  Dec. 31, 2012               $48,017              19,053       28,964
# 18  Dec. 31, 2011               $46,542              18,215       28,327
# 20  Sep. 28, 2012               $12,340               4,853        7,487
# 22  Jun. 29, 2012               $13,085               5,224        7,861
# 24  Mar. 30, 2012               $11,137               4,348        6,789
# 26  Dec. 31, 2013               $46,854              18,421       28,433
# 27  Dec. 31, 2012               $48,017              19,053       28,964
# 29  Sep. 27, 2013               $12,030               4,793        7,237
# ...

# %%
financialdata[financialdata['Date']=='Dec. 31, 2011']
# Out:
#              Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# 0   Dec. 31, 2011               $46,542              18,216       28,326
# 8   Dec. 31, 2011               $46,542              18,215       28,327
# 18  Dec. 31, 2011               $46,542              18,215       28,327
#
#    Selling, general and administrative expenses Other operating charges  \
# 0                                        17,440                     732
# 8                                        17,422                     732
# 18                                       17,422                     732
#
#    OPERATING INCOME Interest income Interest expense  \
# 0            10,154             483              417
# 8            10,173             483              417
# 18           10,173             483              417
#
#    Equity income (loss) - net  ...  \
# 0                         690  ...
# 8                         690  ...
# 18                        690  ...
#
# ...

# %% [markdown]
# ## Data Cleaning
# ### Note! In accounting zero is not same as null value. Zero can mean that the captured recored scored zero but null means the value was not captured. for this reasoning cleaning of this data will not include replacing null with zero or any other figure. Null value rows or columns will not also be deleted because it could just be ok that a value was captured a few times in a row or column but still very very signicant for useful insight
# ### Clean off dollar signs, commas,braackets and empty spaces

# %%
financialdata['NET OPERATING REVENUES'] = financialdata['NET OPERATING REVENUES'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Cost of goods sold'] = financialdata['Cost of goods sold'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['GROSS PROFIT'] = financialdata['GROSS PROFIT'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Selling, general and administrative expenses'] = financialdata['Selling, general and administrative expenses'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Other operating charges'] = financialdata['Other operating charges'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['OPERATING INCOME'] = financialdata['OPERATING INCOME'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Interest income'] = financialdata['Interest income'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Interest expense'] = financialdata['Interest expense'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Equity income (loss) - net'] = financialdata['Equity income (loss) - net'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Other income (loss) - net'] = financialdata['Other income (loss) - net'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['INCOME BEFORE INCOME TAXES'] =financialdata['INCOME BEFORE INCOME TAXES'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Income taxes'] = financialdata['Income taxes'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['CONSOLIDATED NET INCOME'] = financialdata['CONSOLIDATED NET INCOME'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY'] = financialdata['NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['BASIC NET INCOME PER SHARE (in dollars per share)'] = financialdata['BASIC NET INCOME PER SHARE (in dollars per share)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['DILUTED NET INCOME PER SHARE (in dollars per share)'] = financialdata['DILUTED NET INCOME PER SHARE (in dollars per share)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['AVERAGE SHARES OUTSTANDING (in shares)'] = financialdata['AVERAGE SHARES OUTSTANDING (in shares)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Effect of dilutive securities (in shares)'] = financialdata['Effect of dilutive securities (in shares)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['AVERAGE SHARES OUTSTANDING ASSUMING DILUTION (in shares)'] = financialdata['AVERAGE SHARES OUTSTANDING ASSUMING DILUTION (in shares)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['DIVIDENDS PER SHARE (in dollars per share)'] = financialdata['DIVIDENDS PER SHARE (in dollars per share)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['NET OPERATING REVENUES'] = financialdata['NET OPERATING REVENUES'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Less: Net income (loss) attributable to noncontrolling interests'] =financialdata['Less: Net income (loss) attributable to noncontrolling interests'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'] = financialdata['Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Net Income (Loss) Attributable to Noncontrolling Interest'] = financialdata['Net Income (Loss) Attributable to Noncontrolling Interest'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share'] = financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Income (Loss) from Continuing Operations, Per Diluted Share'] = financialdata['Income (Loss) from Continuing Operations, Per Diluted Share'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share'] = financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Discontinued Operation, Tax Effect of Discontinued Operation'] = financialdata['Discontinued Operation, Tax Effect of Discontinued Operation'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Net Income from Continuing Operations'] = financialdata['Net Income from Continuing Operations'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Common Stock, Dividends, Per Share, Declared'] = financialdata['Common Stock, Dividends, Per Share, Declared'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'] = financialdata['Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
financialdata['Income (Loss) from Discontinued Operations (net of income taxes)'] = financialdata['Income (Loss) from Discontinued Operations (net of income taxes)'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
# Out:
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_2504\1697354177.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financialdata['NET OPERATING REVENUES'] = financialdata['NET OPERATING REVENUES'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
# C:\Users\Anih Nathan\AppData\Local\Temp\ipykernel_2504\1697354177.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   financialdata['Cost of goods sold'] = financialdata['Cost of goods sold'].str.replace('$','').str.replace(',','').str.replace('(','-').str.replace(')','').str.replace(' ','')
# ...

# %% [markdown]
# ### Drop off Duplicated rows

# %%
financialdata = financialdata.sort_values(by=['NET OPERATING REVENUES'])
financialdata = financialdata.drop_duplicates(subset='Date')
financialdata
# Out:
#              Date NET OPERATING REVENUES Cost of goods sold GROSS PROFIT  \
# 60  Apr. 01, 2016                  10282               4069         6213
# 15  Apr. 01, 2011                  10517               3948         6569
# 32  Mar. 28, 2014                  10576               4083         6493
# 56  Sep. 30, 2016                  10633               4131         6502
# 50  Apr. 03, 2015                  10711               4103         6608
# 23  Mar. 29, 2013                  11035               4324         6711
# 24  Mar. 30, 2012                  11137               4348         6789
# 37  Oct. 02, 2015                  11427               4577         6850
# 48  Jul. 01, 2016                  11539               4471         7068
# 38  Sep. 26, 2014                  11976               4630         7346
# 29  Sep. 27, 2013                  12030               4793         7237
# 39  Jul. 03, 2015                  12156               4748         7408
# ...

# %% [markdown]
# ### Convert Date column to datetime and the rest to ints and floats

# %%
financialdata['Date'] = pd.to_datetime(financialdata['Date'])


financialdata['NET OPERATING REVENUES'] = financialdata['NET OPERATING REVENUES'].astype(float)
financialdata['Cost of goods sold'] = financialdata['Cost of goods sold'].astype(float)
financialdata['GROSS PROFIT'] = financialdata['GROSS PROFIT'].astype(float)
financialdata['Selling, general and administrative expenses'] = financialdata['Selling, general and administrative expenses'].astype(float)
financialdata['Other operating charges'] = financialdata['Other operating charges'].astype(float)
financialdata['OPERATING INCOME'] = financialdata['OPERATING INCOME'].astype(float)
financialdata['Interest income'] = financialdata['Interest income'].astype(float)
financialdata['Interest expense'] = financialdata['Interest expense'].astype(float)
financialdata['Equity income (loss) - net'] = financialdata['Equity income (loss) - net'].astype(float)
financialdata['Other income (loss) - net'] = financialdata['Other income (loss) - net'].astype(float)
financialdata['INCOME BEFORE INCOME TAXES'] =financialdata['INCOME BEFORE INCOME TAXES'].astype(float)
financialdata['Income taxes'] = financialdata['Income taxes'].astype(float)
financialdata['CONSOLIDATED NET INCOME'] = financialdata['CONSOLIDATED NET INCOME'].astype(float)
financialdata['NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY'] = financialdata['NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY'].astype(float)
financialdata['BASIC NET INCOME PER SHARE (in dollars per share)'] = financialdata['BASIC NET INCOME PER SHARE (in dollars per share)'].astype(float)
financialdata['DILUTED NET INCOME PER SHARE (in dollars per share)'] = financialdata['DILUTED NET INCOME PER SHARE (in dollars per share)'].astype(float)
financialdata['AVERAGE SHARES OUTSTANDING (in shares)'] = financialdata['AVERAGE SHARES OUTSTANDING (in shares)'].astype(float)
financialdata['Effect of dilutive securities (in shares)'] = financialdata['Effect of dilutive securities (in shares)'].astype(float)
financialdata['AVERAGE SHARES OUTSTANDING ASSUMING DILUTION (in shares)'] = financialdata['AVERAGE SHARES OUTSTANDING ASSUMING DILUTION (in shares)'].astype(float)
financialdata['DIVIDENDS PER SHARE (in dollars per share)'] = financialdata['DIVIDENDS PER SHARE (in dollars per share)'].astype(float)
financialdata['NET OPERATING REVENUES'] = financialdata['NET OPERATING REVENUES'].astype(float)
financialdata['Less: Net income (loss) attributable to noncontrolling interests'] =financialdata['Less: Net income (loss) attributable to noncontrolling interests'].astype(float)
financialdata['Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'] = financialdata['Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'].astype(float)
financialdata['Net Income (Loss) Attributable to Noncontrolling Interest'] = financialdata['Net Income (Loss) Attributable to Noncontrolling Interest'].astype(float)
financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share'] = financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share'].astype(float)
financialdata['Income (Loss) from Continuing Operations, Per Diluted Share'] = financialdata['Income (Loss) from Continuing Operations, Per Diluted Share'].astype(float)
financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share'] = financialdata['Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share'].astype(float)
financialdata['Discontinued Operation, Tax Effect of Discontinued Operation'] = financialdata['Discontinued Operation, Tax Effect of Discontinued Operation'].astype(float)
financialdata['Net Income from Continuing Operations'] = financialdata['Net Income from Continuing Operations'].astype(float)
financialdata['Common Stock, Dividends, Per Share, Declared'] = financialdata['Common Stock, Dividends, Per Share, Declared'].astype(float)
financialdata['Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'] = financialdata['Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest'].astype(float)
financialdata['Income (Loss) from Discontinued Operations (net of income taxes)'] = financialdata['Income (Loss) from Discontinued Operations (net of income taxes)'].astype(float)

# %%
financialdata
# Out:
#          Date  NET OPERATING REVENUES  Cost of goods sold  GROSS PROFIT  \
# 60 2016-04-01                 10282.0              4069.0        6213.0
# 15 2011-04-01                 10517.0              3948.0        6569.0
# 32 2014-03-28                 10576.0              4083.0        6493.0
# 56 2016-09-30                 10633.0              4131.0        6502.0
# 50 2015-04-03                 10711.0              4103.0        6608.0
# 23 2013-03-29                 11035.0              4324.0        6711.0
# 24 2012-03-30                 11137.0              4348.0        6789.0
# 37 2015-10-02                 11427.0              4577.0        6850.0
# 48 2016-07-01                 11539.0              4471.0        7068.0
# 38 2014-09-26                 11976.0              4630.0        7346.0
# 29 2013-09-27                 12030.0              4793.0        7237.0
# 39 2015-07-03                 12156.0              4748.0        7408.0
# ...

# %%
financialdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 60 to 6
# Data columns (total 33 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   Date                                                                                                               40 non-null     datetime64[ns]
#  1   NET OPERATING REVENUES                                                                                             40 non-null     float64
#  2   Cost of goods sold                                                                                                 40 non-null     float64
#  3   GROSS PROFIT                                                                                                       40 non-null     float64
# ...

# %% [markdown]
# ### Data Transformation - Add Columns for Year and Quarter

# %%
financialdata['Year'] = pd.DatetimeIndex(financialdata['Date']).year
financialdata['Quarter'] = pd.to_datetime(financialdata['Date']).dt.strftime('%b-%Y')
financialdata
# Out:
#          Date  NET OPERATING REVENUES  Cost of goods sold  GROSS PROFIT  \
# 60 2016-04-01                 10282.0              4069.0        6213.0
# 15 2011-04-01                 10517.0              3948.0        6569.0
# 32 2014-03-28                 10576.0              4083.0        6493.0
# 56 2016-09-30                 10633.0              4131.0        6502.0
# 50 2015-04-03                 10711.0              4103.0        6608.0
# 23 2013-03-29                 11035.0              4324.0        6711.0
# 24 2012-03-30                 11137.0              4348.0        6789.0
# 37 2015-10-02                 11427.0              4577.0        6850.0
# 48 2016-07-01                 11539.0              4471.0        7068.0
# 38 2014-09-26                 11976.0              4630.0        7346.0
# 29 2013-09-27                 12030.0              4793.0        7237.0
# 39 2015-07-03                 12156.0              4748.0        7408.0
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(12,6))
sbn.barplot(x='Quarter', y='NET OPERATING REVENUES', data = financialdata.sort_values(by=['Quarter']))
plt.title("NET OPERATING REVENUES VARIATION OVER TIME")
plt.ylabel("Net Operating Revenue (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x='Quarter', y='GROSS PROFIT', data = financialdata.sort_values(by=['Quarter']))
plt.title("GROSS PROFIT VARIATION OVER TIME")
plt.ylabel("Gross Profit (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x='Quarter', y='Cost of goods sold', data = financialdata.sort_values(by=['Quarter']))
plt.title("COST OF GOOD SOLD VARIATION OVER TIME")
plt.ylabel("Cost of goods sold (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x='Quarter', y='Selling, general and administrative expenses', data = financialdata.sort_values(by=['Quarter']))
plt.title("SELLING,GENERAL AND ADMINISTRATIVE EXPENSES VARIATION OVER TIME")
plt.ylabel("Selling, General and Administrative (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x='Quarter', y='OPERATING INCOME', data = financialdata.sort_values(by=['Quarter']))
plt.title("OPERATING INCOME VARIATION OVER TIME")
plt.ylabel("Operating income (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x='Quarter', y='Interest income', data = financialdata.sort_values(by=['Quarter']))
plt.title("INTEREST INCOME VARIATION OVER TIME")
plt.ylabel("Interest Income (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %%
group1 = financialdata[['NET OPERATING REVENUES','GROSS PROFIT','Cost of goods sold','Selling, general and administrative expenses','OPERATING INCOME','CONSOLIDATED NET INCOME','Interest income']]

# %%
plt.figure(figsize=(12,8))
sbn.barplot(group1)
plt.xticks(rotation=90)
plt.title('COMPARSON OF VARIOUS VARIABLES FROM THE CONSOLIDATED INCOME STATEMENT')
plt.ylabel("Total for the Period (Millions in USD)")
plt.show()

# %% [markdown]
# ### Comparing Discontinued and continued Operation

# %% [markdown]
# ### Comparing Operating revenue with Operating income and gross profit

# %%
group2 = financialdata[['NET OPERATING REVENUES','GROSS PROFIT','OPERATING INCOME']]

# %%
plt.figure(figsize=(10,6))
financialdata.plot(x="Quarter",y=['NET OPERATING REVENUES','GROSS PROFIT','OPERATING INCOME','Cost of goods sold'], kind='line', color=('red','black','purple','green'))
plt.xticks(rotation=90)
plt.title("COMPARISON OF NET OPERATING REVENUES, GROSS PROFIT, COST OF GOODS SOLD, OPERATING INCOME")
plt.ylabel("Value (millions in USD)")
plt.show()

# %%
grouploss = financialdata[['Equity income (loss) - net','Other income (loss) - net','Less: Net income (loss) attributable to noncontrolling interests','Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest','Net Income (Loss) Attributable to Noncontrolling Interest','Income (Loss) from Continuing Operations, Per Basic Share','Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share','Income (Loss) from Continuing Operations, Per Diluted Share','Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share','Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest','Income (Loss) from Discontinued Operations (net of income taxes)']]
lossvariables = ['Equity income (loss) - net','Other income (loss) - net','Less: Net income (loss) attributable to noncontrolling interests','Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest','Net Income (Loss) Attributable to Noncontrolling Interest','Income (Loss) from Continuing Operations, Per Basic Share','Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share','Income (Loss) from Continuing Operations, Per Diluted Share','Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share','Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest','Income (Loss) from Discontinued Operations (net of income taxes)']

# %%
#financialdata.plot(x="Quarter",y=lossvariables, kind='bar', color=('red','black','purple','green'))
plt.figure(figsize=(5,5))
sbn.barplot(grouploss, orient='h')
plt.title("COMPARISON OF DIFFERENT SOURCES OF LOSS FOR THE PERIOD (2009 - 2019)")
plt.xlabel("Amount in Millions of USD")
plt.ylabel("Sources of Loss")
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\Anih Nathan\anaconda3\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\Anih Nathan\anaconda3\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# C:\Users\Anih Nathan\anaconda3\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %% [markdown]
# ## A FOCUS ON EACH OF THE SOURCE OF LOSSES

# %% [markdown]
# ### Equity income (loss)-net

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Equity income (loss) - net', data=financialdata)
plt.ylabel("Equity income (loss)-net (millions in USD)")
plt.title("NET EQUITY INCOME (LOSS)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Other income (loss) - net

# %%
plt.figure(figsize=(10,8))
sbn.lineplot(x="Quarter", y='Other income (loss) - net', data=financialdata)
plt.ylabel("Other income - net (millions in USD)")
plt.title("OTHER INCOME - NET VARIATION OVERTIME")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Less: Net income (loss) attributable to noncontrolling interests

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Less: Net income (loss) attributable to noncontrolling interests', data=financialdata)
plt.title("LESS: NET INCOME (LOSS) ATTRIBUTABLE TO NONCONTROLLING INTERESTS VARIATION OVER TIME")
plt.ylabel("Less: Net income (loss) attributable to noncontrolling interests (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Income (Loss) from Discontinued Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest', data=financialdata)

plt.ylabel("Income (Loss) from Discontinued Operations (millions in USD)")
plt.title(" INCOME (LOSS) FROM DISCONTINUED OPERATIONS, NET OF TAX, INCLUDING PORTIONS ATTRIBUTABLE TO NONCONTROLLING INTEREST")
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### Net Income (Loss) Attributable to Noncontrolling Interest

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Net Income (Loss) Attributable to Noncontrolling Interest', data=financialdata)
plt.title(" NET INCOME (LOSS) ATTRIBUTABLE TO NONCONTROLLING INTEREST")
plt.ylabel("Net Income (Loss) Attributable to Noncontrolling Interest (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share', data=financialdata)
plt.title(" INCOME (LOSS) FROM DISCONTINUED  OPERATION, NET OF TAX, PER BASIC SHARE")
plt.ylabel("Income (Loss) from Discontinued Operation, Net of Tax, Per Basic Share (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Income (Loss) from Continuing Operations, Per Diluted Share

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Income (Loss) from Continuing Operations, Per Diluted Share', data=financialdata)
plt.title(" INCOME (LOSS) FROM CONTINUING  OPERATIONS, PER DILUTED SHARE")
plt.ylabel("Income (Loss) from Continuing Operations, Per Diluted Share (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Discontinued Operation, Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share', data=financialdata)
plt.title(" INCOME (LOSS) FROM DISCONTINUED  OPERATIONS, PER DILUTED SHARE")
plt.ylabel("Income (Loss) from Discontinued Operation, Net of Tax, Per Diluted Share (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Focus on Income (Loss) from continung operations net of tax, incuding portion attributable to noncontrolling interest

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Income (Loss) from Continuing Operations, Net of Tax, Including Portion Attributable to Noncontrolling Interest', data=financialdata)
plt.title(" INCOME (LOSS) FROM CONTINUING  OPERATIONS, NET OF TAX, NONCONTROLLING INTEREST")
plt.ylabel("Income (Loss) from Continuing Operations,Net of Tax, Noncontrolling Interest (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Income (Loss) from Discontinued Operations (net of income taxes)

# %%
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='Income (Loss) from Discontinued Operations (net of income taxes)', data=financialdata)
plt.title(" INCOME (LOSS) FROM DISONTINUED OPERATIONS, (NET OF INCOME TAX)")
plt.ylabel("'Income (Loss) from Discontinued Operations (net of income taxes) (millions in USD)")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CONSOLIDATED NET INCOME

# %%
#CONSOLIDATED NET INCOME
plt.figure(figsize=(10,8))
sbn.barplot(x="Quarter", y='CONSOLIDATED NET INCOME', data=financialdata)
plt.title(" CONSOLIDATED NET INCOME")
plt.ylabel("'Consolidated net income (millions in USD)")
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Net Income, Operating Income Revenue and Gross income

# %%
plt.figure(figsize=(10,6))
financialdata.plot(x="Quarter",y=[NET OPERATING REVENUES','GROSS PROFIT','CONSOLIDATED NET INCOME','Cost of goods sold'], kind='line', color=('red','black','purple','green'))
plt.xticks(rotation=90)
plt.title("COMPARISON OF NET OPERATING REVENUES, GROSS PROFIT, COST OF GOODS SOLD, OPERATING INCOME")
plt.show()

# %% [markdown]
# # Net Income from Continuing Operations

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x="Quarter", y='Net Income from Continuing Operations', data=financialdata)
plt.xticks(rotation=90)
plt.title("NET INCOME FROM CONTINUING OPERATION")
plt.ylabel("Net income from continuing operation (millions in USD)")
plt.show()

# %%
twenty17 = financialdata[financialdata['Year']==2017]

# %%
twenty17
# Out:
#          Date  NET OPERATING REVENUES  Cost of goods sold  GROSS PROFIT  \
# 52 2017-12-31                 35410.0             13256.0       22154.0
# 65 2017-09-29                  9078.0              3394.0        5684.0
# 69 2017-03-31                  9118.0              3513.0        5605.0
# 57 2017-06-30                  9702.0              3659.0        6043.0
#
#     Selling, general and administrative expenses  Other operating charges  \
# 52                                       12496.0                   2157.0
# 65                                        3245.0                    194.0
# 69                                        3352.0                    290.0
# 57                                        3142.0                    823.0
#
#     OPERATING INCOME  Interest income  Interest expense  \
# 52            7501.0            677.0             841.0
# 65            2245.0            175.0             208.0
# 69            1963.0            155.0             192.0
# ...

# %%
sbn.lineplot(x="Quarter", y='Other operating charges', data=twenty17)
plt.xticks(rotation=90)
plt.title("OTHER OPERATION CHARGES")
plt.ylabel("Other Operating Charges (millions in USD)")
# Out:
# Text(0, 0.5, 'Other Operating Charges (millions in USD)')

# %%
plt.figure(figsize=(10,6))
sbn.barplot(x="Quarter", y='Other operating charges', data=financialdata)
plt.xticks(rotation=90)
plt.title("OTHER OPERATION CHARGES")
plt.ylabel("Other Operating Charges (millions in USD)")
# Out:
# Text(0, 0.5, 'Other Operating Charges (millions in USD)')

# %%
financialdata.plot(x="Quarter", y=['NET OPERATING REVENUES','OPERATING INCOME','CONSOLIDATED NET INCOME'], kind='line')
plt.xticks(rotation=90)
plt.title("NET INCOME FROM CONTINUING OPERATION")
plt.ylabel("Net income from continuing operation (millions in USD)")
plt.show()
